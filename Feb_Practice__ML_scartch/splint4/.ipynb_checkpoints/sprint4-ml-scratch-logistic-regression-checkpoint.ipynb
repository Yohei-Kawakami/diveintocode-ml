# %% [markdown]
# ## データ分析の趣旨
# iris dataにおける'versicolor', 'virginica'を分類することを目的とし、説明変数にsepal length (cm)と  'petal length (cm)'
# をとり、簡単なEDAで仮説をたててから検証する。

# %%
# import module
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
# import iris data
from sklearn.datasets import load_iris
iris_dataset = load_iris()
list(iris_dataset.target_names)
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
# Check an iris dataset
# iris_dataset

# %%
# mold the array of iris to dataframe
X = pd.DataFrame(np.array(iris_dataset.data))

# %%
# head
X.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
# info
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
# describe
X.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# nan
df_iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Species         0
# dtype: int64

# %% [markdown]
# 欠損値がないので、そのまま分析を進める。

# %%
# rename the columns
columns_dic = {0: 'sepal_length', 1: 'sepal_width', 2: 'petal_length', 3: 'petal_width'}

X.rename(columns= columns_dic, inplace=True)
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# mold the array to dataframe
Y = pd.DataFrame(np.array(iris_dataset.target)) 

# rename a column
Y = Y.rename(columns = {0:'Species'})

# check the dataset
Y['Species'].value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Species, dtype: int64

# %%
# combine features and categorie
df_iris = X.join(Y)

# check
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
columns_process = ["sepal_length", "petal_length", "Species"]

# generate a dataframe for analyzing iris dataset
df_iris_del_index = df_iris[df_iris.Species != 0] # virgicolor and virginica

#　analysis about 'versicolor', 'virginica'
df_train_test = df_iris_del_index.loc[:, columns_process]
df_train_test['Species'] -= 1
df_train_test['Species'].unique()
# Out:
# array([0, 1])

# %%
'''
Overview the histgram and plot
'''
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(15, 15))

sns.pairplot(df_train_test, vars=df_train_test.iloc[:,:2].columns, 
             hue="Species", palette="husl")

# %%
# plot box plot
fig = plt.figure(figsize=(6, 6))
ax1 = plt.subplot(1,2,1)
ax1 = sns.boxplot(x="Species", y="sepal_length", 
                  data=df_train_test, palette="husl") 
ax2 = plt.subplot(1,2,2)
ax2 = sns.boxplot(x="Species", y="petal_length", 
                  data=df_train_test, palette="husl")

# %%
# individual variable and non-dividual variable
X = df_train_test.iloc[:, :-1].values # by number/ values --> serries
y = df_train_test.loc[:, "Species"].values # by column's name

# for spliting train and test
(X_train, X_test, y_train, y_test) = train_test_split(X, y, test_size = 0.3)

# %% [markdown]
# ###### 【仮説】
# "petal_length"が5cm前後で、'versicolor', 'virginica'が分類される。
# <br>"sepal_lenth"では、6.3cm前後で分類できるように見えるが、"petal_length"に比べ、信頼区間の精度は劣るのではないか。

# %% [markdown]
# ###### 【検証方法】
# ロジスティック回帰分析を用い、適切なパラメータを求め、二種分類の式を作成する。

# %% [markdown]
# ### 【問題1】ロジスティック回帰のクラスを作成する
# ロジスティック回帰のクラスを作成し、Sprint2で作成した分類のパイプラインに組み込んでください。
# <br>クラスの基本構造はSprint3の線形回帰を参考にし、名前はScratchLogisticRegressionとしてください。
# <br>
# <br>メソッドやパラメータなどはscikit-learnを参考にしてください。
# <br>推定関係ではラベルを出力するpredictメソッドと、確率を出力するpredict_probaメソッドの2種類を作成します。
# <br>sklearn.linear_model.LinearRegression — scikit-learn 0.20.0 documentation
# <br>
# <br>検証段階ではJupyter Notebook上で書いていき、最終的にはpyファイルにモジュールとしてまとめてください。

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import math

class ScratchLogisticRegression():
    """
    ロジスティック回帰のスクラッチ実装

    Parameters
    ----------
    num_iter : int
      イテレーション数
    lr : float
      学習率
    no_bias : bool
      バイアス項を入れない場合はTrue
    verbose : bool
      学習過程を出力する場合はTrue

    Attributes
    ----------
    self.coef_ : 次の形のndarray, shape (n_features,)
      パラメータ
    self.loss : 次の形のndarray, shape (self.iter,)
      学習用データに対する損失の記録
    self.val_loss : 次の形のndarray, shape (self.iter,)
      検証用データに対する損失の記録

    """

    def __init__(self, num_iter=1000, lr=0.01, bias=True, verbose=True, lamda=0.01, num_feature=2, threshold=0.5):
        # ハイパーパラメータを属性として記録
        self.num_iter = num_iter
        self.lr = lr
        self.bias = bias
        self.verbose = verbose
        self.n = 0
        self.lamda = lamda
        self.threshold = threshold
        
        # thetaを保存するリストを作成
        self.theta = np.zeros((self.num_iter, int(bias) + num_feature))
        
        # 損失を記録する配列を用意
        self.loss = np.zeros(self.num_iter)
        self.use_loss = np.zeros(self.num_iter)        
        self.val_loss = np.zeros(self.num_iter)
        

    def fit(self, X, y, X_val=None, y_val=None):
        """
        線形回帰を学習する。検証用データが入力された場合はそれに対する損失と精度もイテレーションごとに計算する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            学習用データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            学習用データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証用データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証用データの正解値
        """
        m = len(X)
        # 基本統計量
        mu = X.mean(axis=0) # 平均の算出 （axis=0を指定して列毎に標準化）
        sigma = X.std(axis=0) # 標準偏差の算出 （axis=0を指定して列毎に標準化）

        # 標準化処理
        X = (X - mu)/sigma
        
        # バイアス項の挿入
        if self.bias:
            X = np.hstack((np.ones(m).reshape(m, 1),X))
        # 特徴量の数取得
        self.n = X.shape[1]
            
        # X_vaにもバイアスの追加
        if type(X_val)==np.ndarray:
            m_val = len(X_val)
             # 基本統計量
            mu_val = X_val.mean(axis=0) # 平均の算出 （axis=0を指定して列毎に標準化）
            sigma_val = X_val.std(axis=0) # 標準偏差の算出 （axis=0を指定して列毎に標準化）

            # 標準化処理
            X_val = (X_val - mu_val)/sigma_val
            # バイアス項の挿入
            X_val = np.hstack((np.ones(m_val).reshape(m_val, 1), X_val))
        
        # シータの初期化
        self._init_theta()
        
        # 最急降下法
        if type(X_val)==np.ndarray:
            self._gradient_descent(X, y, X_val, y_val)
            
        else:
            self._gradient_descent(X, y)            
    
    def _init_theta(self):
        """
        self.coef_: 次の形のndarray, shape(n_features)
        パラメータをランダムに初期化します。
        """
        self.coef_ = np.random.rand(self.n, 1)
        
    def sigmoid(z):
        e = math.e
        return 1/(1+(e**-z))
        
    def _logistic_hypothesis(self, X):
        """
        線形の仮定関数を計算する

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
          学習データ

        Returns
        -------
          次の形のndarray, shape (n_samples, 1)
          線形の仮定関数による推定結果
        """

        hx = sigmoid(np.dot(X, self.coef_))
                     
        return hx
    

    def _gradient_descent(self, X, y, X_val=None, y_val=None):
        """
        Parameters
         ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            学習用データの特徴量
        y : 次の形のndarray, shape (n_samples, )
            学習用データの正解値
        X_val : 次の形のndarray, shape (n_samples, n_features)
            検証用データの特徴量
        y_val : 次の形のndarray, shape (n_samples, )
            検証用データの正解値
        """
        
        alpha = self.lr
        m = len(X)
        y = y.reshape(m, 1)
        hx = self._logistic_hypothesis(X)
        count = 0

        for i in range(self.num_iter):
            if self.bias:
                coef_bias_zero = self.coef_.copy()
                coef_bias_zero[0] = 0
                
            self.coef_ = self.coef_ - alpha * ((1/m) * sum(np.dot(X.T, self._logistic_hypothesis(X)-y)) + (self.lamda/m)*coef_bias_zero)
            
            self.theta[i] = self.coef_.T
            hx = self._logistic_hypothesis(X)        
            
            if self.verbose:
                log = 'COUNT:{}, 目的関数:{}'
                #verboseをTrueにした際は学習過程を出力
                print(log.format(count+1, self.cross_entropy(hx, y)))

            # trainデータのlossのリザルトを出す
            if self.verbose:
                self.loss[i] = self.cross_entropy(hx, y)
                
            # X_val入力ある場合lossのリザルトを出す
            if type(X_val) == np.ndarray:
                val_pred = self._logistic_hypothesis(X_val)
                self.val_loss[i] = self.cross_entropy(val_pred, y_val)

            count += 1
    

    def predict(self, X):
        """
        線形回帰を使い推定する。

        Parameters
        ----------
        X : 次の形のndarray, shape (n_samples, n_features)
            サンプル

        Returns
        -------
            次の形のndarray, shape (n_samples, 1)
            線形回帰による推定結果
        """
        
        # 標準化処理
        mu = X.mean(axis=0) # 平均の算出 （axis=0を指定して列毎に標準化）
        sigma = X.std(axis=0) # 標準偏差の算出 （axis=0を指定して列毎に標準化）

        # 標準化処理
        X = (X -mu)/sigma
        
        if self.bias:
            m = len(X)
            X = np.hstack((np.ones(m).reshape(m,1), X))
        predict =  sigmoid(np.dot(X, self.coef_))
        predict[predict > self.threshold] = 1
        predict[predict <= self.threshold] = 0
        
        return predict
    
    
    def predict_proba(self, X):
        # 標準化処理
        mu = X.mean(axis=0) # 平均の算出 （axis=0を指定して列毎に標準化）
        sigma = X.std(axis=0) # 標準偏差の算出 （axis=0を指定して列毎に標準化）

        # 標準化処理
        X = (X -mu)/sigma
        
        if self.bias:
            m = len(X)
            X = np.hstack((np.ones(m).reshape(m,1), X))
        predict =  sigmoid(np.dot(X, self.coef_))

        return predict
        
                
    def cross_entropy(self, hx, y):
        """
        クロスエントロピーの計算

        Parameters
        ----------
        hx : 次の形のndarray, shape (n_samples,)
          推定した値
        y : 次の形のndarray, shape (n_samples,)
          正解値

        Returns
        ----------
        mse : numpy.float
          平均二乗誤差
        """
        # リシェイプ
        y = y.reshape(len(y), 1)
        m = len(y)
        
        J = (1/m)*sum(sum(-(y*np.log(hx))-(1-y)*np.log(1-hx))) + (self.lamda/(2*m))*sum((sum((self.coef_)**2)))
        return J

# %%
slr = ScratchLogisticRegression()
slr.fit(X_train, y_train, X_test, y_test)
# Out:
# COUNT:1, 目的関数:0.5408297081546403
# COUNT:2, 目的関数:0.5401188338093214
# COUNT:3, 目的関数:0.5394180812567965
# COUNT:4, 目的関数:0.5387272562093689
# COUNT:5, 目的関数:0.5380461690960939
# COUNT:6, 目的関数:0.5373746349269697
# COUNT:7, 目的関数:0.53671247316151
# COUNT:8, 目的関数:0.536059507581557
# COUNT:9, 目的関数:0.5354155661681818
# COUNT:10, 目的関数:0.5347804809825364
# COUNT:11, 目的関数:0.5341540880505214
# COUNT:12, 目的関数:0.5335362272511359
# COUNT:13, 目的関数:0.5329267422083857
# COUNT:14, 目的関数:0.5323254801866271
# COUNT:15, 目的関数:0.5317322919892278
# COUNT:16, 目的関数:0.5311470318604316
# COUNT:17, 目的関数:0.5305695573903189
# COUNT:18, 目的関数:0.5299997294227528
# COUNT:19, 目的関数:0.5294374119662142
# COUNT:20, 目的関数:0.5288824721074221
# COUNT:21, 目的関数:0.5283347799276473
# COUNT:22, 目的関数:0.5277942084216286
# COUNT:23, 目的関数:0.5272606334189986
# COUNT:24, 目的関数:0.5267339335081375
# COUNT:25, 目的関数:0.5262139899623738
# COUNT:26, 目的関数:0.5257006866684464
# COUNT:27, 目的関数:0.5251939100571601
# COUNT:28, 目的関数:0.5246935490361517
# COUNT:29, 目的関数:0.5241994949247041
# COUNT:30, 目的関数:0.5237116413905327
# COUNT:31, 目的関数:0.5232298843884825
# COUNT:32, 目的関数:0.5227541221010691
# COUNT:33, 目的関数:0.5222842548808053
# COUNT:34, 目的関数:0.5218201851942501
# COUNT:35, 目的関数:0.5213618175677249
# COUNT:36, 目的関数:0.5209090585346436
# COUNT:37, 目的関数:0.5204618165843989
# COUNT:38, 目的関数:0.5200200021127551
# COUNT:39, 目的関数:0.5195835273737025
# COUNT:40, 目的関数:0.5191523064327171
# COUNT:41, 目的関数:0.5187262551213871
# COUNT:42, 目的関数:0.5183052909933575
# COUNT:43, 目的関数:0.5178893332815482
# COUNT:44, 目的関数:0.5174783028566143
# COUNT:45, 目的関数:0.5170721221865927
# COUNT:46, 目的関数:0.5166707152977111
# COUNT:47, 目的関数:0.5162740077363145
# COUNT:48, 目的関数:0.515881926531873
# COUNT:49, 目的関数:0.515494400161041
# COUNT:50, 目的関数:0.5151113585127323
# COUNT:51, 目的関数:0.5147327328541731
# COUNT:52, 目的関数:0.5143584557979121
# COUNT:53, 目的関数:0.5139884612697508
# COUNT:54, 目的関数:0.5136226844775654
# COUNT:55, 目的関数:0.5132610618809941
# COUNT:56, 目的関数:0.5129035311619613
# COUNT:57, 目的関数:0.5125500311960147
# COUNT:58, 目的関数:0.5122005020244481
# COUNT:59, 目的関数:0.5118548848271843
# COUNT:60, 目的関数:0.5115131218963993
# COUNT:61, 目的関数:0.5111751566108593
# COUNT:62, 目的関数:0.5108409334109524
# COUNT:63, 目的関数:0.5105103977743919
# COUNT:64, 目的関数:0.5101834961925741
# COUNT:65, 目的関数:0.5098601761475636
# COUNT:66, 目的関数:0.5095403860896948
# COUNT:67, 目的関数:0.5092240754157661
# COUNT:68, 目的関数:0.5089111944478112
# COUNT:69, 目的関数:0.5086016944124293
# COUNT:70, 目的関数:0.5082955274206569
# COUNT:71, 目的関数:0.5079926464483671
# COUNT:72, 目的関数:0.5076930053171775
# COUNT:73, 目的関数:0.5073965586758554
# COUNT:74, 目的関数:0.5071032619822025
# COUNT:75, 目的関数:0.5068130714854064
# COUNT:76, 目的関数:0.5065259442088463
# COUNT:77, 目的関数:0.5062418379333354
# COUNT:78, 目的関数:0.5059607111807931
# COUNT:79, 目的関数:0.5056825231983295
# COUNT:80, 目的関数:0.5054072339427347
# COUNT:81, 目的関数:0.5051348040653558
# COUNT:82, 目的関数:0.5048651948973564
# COUNT:83, 目的関数:0.5045983684353422
# COUNT:84, 目的関数:0.5043342873273479
# COUNT:85, 目的関数:0.5040729148591683
# COUNT:86, 目的関数:0.503814214941031
# COUNT:87, 目的関数:0.5035581520945951
# COUNT:88, 目的関数:0.50330469144027
# COUNT:89, 目的関数:0.5030537986848453
# COUNT:90, 目的関数:0.5028054401094216
# COUNT:91, 目的関数:0.5025595825576337
# COUNT:92, 目的関数:0.5023161934241595
# COUNT:93, 目的関数:0.5020752406435077
# COUNT:94, 目的関数:0.5018366926790724
# COUNT:95, 目的関数:0.5016005185124502
# COUNT:96, 目的関数:0.5013666876330141
# COUNT:97, 目的関数:0.5011351700277322
# COUNT:98, 目的関数:0.5009059361712315
# COUNT:99, 目的関数:0.5006789570160923
# COUNT:100, 目的関数:0.5004542039833735
# COUNT:101, 目的関数:0.5002316489533584
# COUNT:102, 目的関数:0.5000112642565173
# COUNT:103, 目的関数:0.499793022664682
# COUNT:104, 目的関数:0.499576897382421
# COUNT:105, 目的関数:0.49936286203861785
# COUNT:106, 目的関数:0.49915089067824187
# COUNT:107, 目的関数:0.4989409577543062
# COUNT:108, 目的関数:0.498733038120014
# COUNT:109, 目的関数:0.4985271070210783
# COUNT:110, 目的関数:0.49832314008821926
# COUNT:111, 目的関数:0.4981211133298329
# COUNT:112, 目的関数:0.4979210031248196
# COUNT:113, 目的関数:0.4977227862155795
# COUNT:114, 目的関数:0.4975264397011612
# COUNT:115, 目的関数:0.4973319410305658
# COUNT:116, 目的関数:0.49713926799619695
# COUNT:117, 目的関数:0.49694839872745783
# COUNT:118, 目的関数:0.49675931168449095
# COUNT:119, 目的関数:0.496571985652052
# COUNT:120, 目的関数:0.49638639973352233
# COUNT:121, 目的関数:0.49620253334504794
# COUNT:122, 目的関数:0.4960203662098107
# COUNT:123, 目的関数:0.49583987835242077
# COUNT:124, 目的関数:0.49566105009343053
# COUNT:125, 目的関数:0.4954838620439686
# COUNT:126, 目的関数:0.49530829510048774
# COUNT:127, 目的関数:0.49513433043962657
# COUNT:128, 目的関数:0.49496194951317946
# COUNT:129, 目的関数:0.49479113404317315
# COUNT:130, 目的関数:0.49462186601705077
# COUNT:131, 目的関数:0.494454127682954
# COUNT:132, 目的関数:0.49428790154510827
# COUNT:133, 目的関数:0.49412317035930087
# COUNT:134, 目的関数:0.4939599171284563
# COUNT:135, 目的関数:0.4937981250983042
# COUNT:136, 目的関数:0.493637777753136
# COUNT:137, 目的関数:0.49347885881164943
# COUNT:138, 目的関数:0.4933213522228805
# COUNT:139, 目的関数:0.49316524216221724
# COUNT:140, 目的関数:0.49301051302749727
# COUNT:141, 目的関数:0.49285714943518355
# COUNT:142, 目的関数:0.4927051362166181
# COUNT:143, 目的関数:0.4925544584143533
# COUNT:144, 目的関数:0.4924051012785572
# COUNT:145, 目的関数:0.4922570502634893
# COUNT:146, 目的関数:0.4921102910240495
# COUNT:147, 目的関数:0.4919648094123976
# COUNT:148, 目的関数:0.4918205914746353
# COUNT:149, 目的関数:0.49167762344755866
# COUNT:150, 目的関数:0.49153589175547646
# COUNT:151, 目的関数:0.4913953830070851
# COUNT:152, 目的関数:0.4912560839924119
# COUNT:153, 目的関数:0.4911179816798162
# COUNT:154, 目的関数:0.4909810632130466
# COUNT:155, 目的関数:0.49084531590836045
# COUNT:156, 目的関数:0.4907107272516966
# COUNT:157, 目的関数:0.49057728489590435
# COUNT:158, 目的関数:0.4904449766580241
# COUNT:159, 目的関数:0.4903137905166233
# COUNT:160, 目的関数:0.4901837146091831
# COUNT:161, 目的関数:0.49005473722953274
# COUNT:162, 目的関数:0.4899268468253365
# COUNT:163, 目的関数:0.4898000319956248
# COUNT:164, 目的関数:0.489674281488378
# COUNT:165, 目的関数:0.48954958419814865
# COUNT:166, 目的関数:0.4894259291637358
# COUNT:167, 目的関数:0.48930330556589824
# COUNT:168, 目的関数:0.489181702725112
# COUNT:169, 目的関数:0.4890611100993719
# COUNT:170, 目的関数:0.4889415172820321
# COUNT:171, 目的関数:0.48882291399968547
# COUNT:172, 目的関数:0.48870529011008806
# COUNT:173, 目的関数:0.4885886356001143
# COUNT:174, 目的関数:0.48847294058375595
# COUNT:175, 目的関数:0.4883581953001567
# COUNT:176, 目的関数:0.4882443901116794
# COUNT:177, 目的関数:0.48813151550201345
# COUNT:178, 目的関数:0.48801956207431313
# COUNT:179, 目的関数:0.487908520549372
# COUNT:180, 目的関数:0.4877983817638295
# COUNT:181, 目的関数:0.4876891366684101
# COUNT:182, 目的関数:0.48758077632619296
# COUNT:183, 目的関数:0.4874732919109163
# COUNT:184, 目的関数:0.48736667470530765
# COUNT:185, 目的関数:0.48726091609944766
# COUNT:186, 目的関数:0.4871560075891615
# COUNT:187, 目的関数:0.4870519407744368
# COUNT:188, 目的関数:0.48694870735787454
# COUNT:189, 目的関数:0.4868462991431634
# COUNT:190, 目的関数:0.48674470803358205
# COUNT:191, 目的関数:0.48664392603052675
# COUNT:192, 目的関数:0.48654394523206845
# COUNT:193, 目的関数:0.48644475783153057
# COUNT:194, 目的関数:0.48634635611609434
# COUNT:195, 目的関数:0.4862487324654264
# COUNT:196, 目的関数:0.4861518793503332
# COUNT:197, 目的関数:0.48605578933143523
# COUNT:198, 目的関数:0.4859604550578664
# COUNT:199, 目的関数:0.4858658692659942
# COUNT:200, 目的関数:0.4857720247781647
# COUNT:201, 目的関数:0.4856789145014644
# COUNT:202, 目的関数:0.4855865314265075
# COUNT:203, 目的関数:0.48549486862624036
# COUNT:204, 目的関数:0.4854039192547702
# COUNT:205, 目的関数:0.4853136765462089
# COUNT:206, 目的関数:0.48522413381353996
# COUNT:207, 目的関数:0.48513528444750276
# COUNT:208, 目的関数:0.485047121915496
# COUNT:209, 目的関数:0.48495963976050005
# COUNT:210, 目的関数:0.4848728316000162
# COUNT:211, 目的関数:0.48478669112502343
# COUNT:212, 目的関数:0.48470121209895345
# COUNT:213, 目的関数:0.48461638835668336
# COUNT:214, 目的関数:0.48453221380354256
# COUNT:215, 目的関数:0.4844486824143377
# COUNT:216, 目的関数:0.4843657882323933
# COUNT:217, 目的関数:0.4842835253686084
# COUNT:218, 目的関数:0.4842018880005279
# COUNT:219, 目的関数:0.48412087037142904
# COUNT:220, 目的関数:0.4840404667894238
# COUNT:221, 目的関数:0.4839606716265742
# COUNT:222, 目的関数:0.4838814793180237
# COUNT:223, 目的関数:0.4838028843611405
# COUNT:224, 目的関数:0.48372488131467706
# COUNT:225, 目的関数:0.48364746479794085
# COUNT:226, 目的関数:0.4835706294899797
# COUNT:227, 目的関数:0.4834943701287798
# COUNT:228, 目的関数:0.4834186815104759
# COUNT:229, 目的関数:0.4833435584885751
# COUNT:230, 目的関数:0.4832689959731921
# COUNT:231, 目的関数:0.48319498893029644
# COUNT:232, 目的関数:0.4831215323809734
# COUNT:233, 目的関数:0.4830486214006921
# COUNT:234, 目的関数:0.48297625111859166
# COUNT:235, 目的関数:0.48290441671677165
# COUNT:236, 目的関数:0.48283311342959884
# COUNT:237, 目的関数:0.48276233654302164
# COUNT:238, 目的関数:0.4826920813938967
# COUNT:239, 目的関数:0.4826223433693249
# COUNT:240, 目的関数:0.4825531179059992
# COUNT:241, 目的関数:0.48248440048955993
# COUNT:242, 目的関数:0.4824161866539628
# COUNT:243, 目的関数:0.4823484719808545
# COUNT:244, 目的関数:0.48228125209895856
# COUNT:245, 目的関数:0.48221452268347115
# COUNT:246, 目的関数:0.48214827945546584
# COUNT:247, 目的関数:0.48208251818130593
# COUNT:248, 目的関数:0.48201723467206725
# COUNT:249, 目的関数:0.4819524247829701
# COUNT:250, 目的関数:0.4818880844128175
# COUNT:251, 目的関数:0.4818242095034441
# COUNT:252, 目的関数:0.4817607960391727
# COUNT:253, 目的関数:0.48169784004627775
# COUNT:254, 目的関数:0.4816353375924592
# COUNT:255, 目的関数:0.481573284786321
# COUNT:256, 目的関数:0.48151167777686044
# COUNT:257, 目的関数:0.4814505127529631
# COUNT:258, 目的関数:0.4813897859429067
# COUNT:259, 目的関数:0.48132949361386995
# COUNT:260, 目的関数:0.48126963207145135
# COUNT:261, 目的関数:0.48121019765919343
# COUNT:262, 目的関数:0.48115118675811336
# COUNT:263, 目的関数:0.48109259578624336
# COUNT:264, 目的関数:0.4810344211981739
# COUNT:265, 目的関数:0.4809766594846068
# COUNT:266, 目的関数:0.48091930717191184
# COUNT:267, 目的関数:0.48086236082169287
# COUNT:268, 目的関数:0.48080581703035885
# COUNT:269, 目的関数:0.4807496724286986
# COUNT:270, 目的関数:0.4806939236814663
# COUNT:271, 目的関数:0.48063856748697065
# COUNT:272, 目的関数:0.4805836005766672
# COUNT:273, 目的関数:0.48052901971476214
# COUNT:274, 目的関数:0.48047482169781713
# COUNT:275, 目的関数:0.48042100335436094
# COUNT:276, 目的関数:0.4803675615445087
# COUNT:277, 目的関数:0.48031449315958286
# COUNT:278, 目的関数:0.4802617951217427
# COUNT:279, 目的関数:0.4802094643836169
# COUNT:280, 目的関数:0.48015749792794277
# COUNT:281, 目的関数:0.48010589276720966
# COUNT:282, 目的関数:0.48005464594330777
# COUNT:283, 目的関数:0.48000375452718075
# COUNT:284, 目的関数:0.4799532156184853
# COUNT:285, 目的関数:0.4799030263452542
# COUNT:286, 目的関数:0.47985318386356257
# COUNT:287, 目的関数:0.4798036853572018
# COUNT:288, 目的関数:0.4797545280373555
# COUNT:289, 目的関数:0.47970570914228094
# COUNT:290, 目的関数:0.4796572259369958
# COUNT:291, 目的関数:0.4796090757129661
# COUNT:292, 目的関数:0.4795612557878014
# COUNT:293, 目的関数:0.4795137635049543
# COUNT:294, 目的関数:0.4794665962334214
# COUNT:295, 目的関数:0.4794197513674496
# COUNT:296, 目的関数:0.4793732263262482
# COUNT:297, 目的関数:0.47932701855370224
# COUNT:298, 目的関数:0.47928112551809
# COUNT:299, 目的関数:0.4792355447118074
# COUNT:300, 目的関数:0.47919027365109096
# COUNT:301, 目的関数:0.47914530987574966
# COUNT:302, 目的関数:0.47910065094889515
# COUNT:303, 目的関数:0.4790562944566826
# COUNT:304, 目的関数:0.4790122380080467
# COUNT:305, 目的関数:0.4789684792344477
# COUNT:306, 目的関数:0.4789250157896169
# COUNT:307, 目的関数:0.4788818453493083
# COUNT:308, 目的関数:0.47883896561105127
# COUNT:309, 目的関数:0.4787963742939083
# COUNT:310, 目的関数:0.47875406913823415
# COUNT:311, 目的関数:0.4787120479054388
# COUNT:312, 目的関数:0.47867030837775626
# COUNT:313, 目的関数:0.47862884835800984
# COUNT:314, 目的関数:0.4785876656693891
# COUNT:315, 目的関数:0.47854675815522046
# COUNT:316, 目的関数:0.4785061236787497
# COUNT:317, 目的関数:0.4784657601229204
# COUNT:318, 目的関数:0.47842566539015874
# COUNT:319, 目的関数:0.4783858374021606
# COUNT:320, 目的関数:0.4783462740996802
# COUNT:321, 目的関数:0.4783069734423231
# COUNT:322, 目的関数:0.47826793340834095
# COUNT:323, 目的関数:0.4782291519944272
# COUNT:324, 目的関数:0.4781906272155216
# COUNT:325, 目的関数:0.4781523571046061
# COUNT:326, 目的関数:0.4781143397125175
# COUNT:327, 目的関数:0.4780765731077491
# COUNT:328, 目的関数:0.47803905537626323
# COUNT:329, 目的関数:0.4780017846213041
# COUNT:330, 目的関数:0.47796475896321106
# COUNT:331, 目的関数:0.4779279765392376
# COUNT:332, 目的関数:0.47789143550336854
# COUNT:333, 目的関数:0.4778551340261437
# COUNT:334, 目的関数:0.477819070294482
# COUNT:335, 目的関数:0.4777832425115044
# COUNT:336, 目的関数:0.4777476488963664
# COUNT:337, 目的関数:0.4777122876840856
# COUNT:338, 目的関数:0.477677157125376
# COUNT:339, 目的関数:0.4776422554864808
# COUNT:340, 目的関数:0.47760758104901063
# COUNT:341, 目的関数:0.4775731321097813
# COUNT:342, 目的関数:0.4775389069806557
# COUNT:343, 目的関数:0.4775049039883844
# COUNT:344, 目的関数:0.4774711214744518
# COUNT:345, 目的関数:0.477437557794922
# COUNT:346, 目的関数:0.4774042113202881
# COUNT:347, 目的関数:0.47737108043531995
# COUNT:348, 目的関数:0.47733816353891934
# COUNT:349, 目的関数:0.4773054590439712
# COUNT:350, 目的関数:0.4772729653772007
# COUNT:351, 目的関数:0.47724068097903005
# COUNT:352, 目的関数:0.47720860430343687
# COUNT:353, 目的関数:0.47717673381781717
# COUNT:354, 目的関数:0.4771450680028448
# COUNT:355, 目的関数:0.47711360535233793
# COUNT:356, 目的関数:0.4770823443731235
# COUNT:357, 目的関数:0.47705128358490523
# COUNT:358, 目的関数:0.4770204215201315
# COUNT:359, 目的関数:0.47698975672386745
# COUNT:360, 目的関数:0.4769592877536652
# COUNT:361, 目的関数:0.4769290131794393
# COUNT:362, 目的関数:0.4768989315833399
# COUNT:363, 目的関数:0.47686904155962995
# COUNT:364, 目的関数:0.4768393417145638
# COUNT:365, 目的関数:0.4768098306662664
# COUNT:366, 目的関数:0.4767805070446133
# COUNT:367, 目的関数:0.4767513694911138
# COUNT:368, 目的関数:0.47672241665879383
# COUNT:369, 目的関数:0.47669364721208196
# COUNT:370, 目的関数:0.47666505982669405
# COUNT:371, 目的関数:0.47663665318952336
# COUNT:372, 目的関数:0.4766084259985268
# COUNT:373, 目的関数:0.47658037696261724
# COUNT:374, 目的関数:0.47655250480155403
# COUNT:375, 目的関数:0.47652480824583543
# COUNT:376, 目的関数:0.4764972860365946
# COUNT:377, 目的関数:0.47646993692549144
# COUNT:378, 目的関数:0.4764427596746135
# COUNT:379, 目的関数:0.4764157530563687
# COUNT:380, 目的関数:0.4763889158533882
# COUNT:381, 目的関数:0.4763622468584241
# COUNT:382, 目的関数:0.4763357448742517
# COUNT:383, 目的関数:0.4763094087135707
# COUNT:384, 目的関数:0.4762832371989093
# COUNT:385, 目的関数:0.4762572291625293
# COUNT:386, 目的関数:0.47623138344632926
# COUNT:387, 目的関数:0.47620569890175407
# COUNT:388, 目的関数:0.4761801743897003
# COUNT:389, 目的関数:0.47615480878042676
# COUNT:390, 目的関数:0.4761296009534625
# COUNT:391, 目的関数:0.47610454979751915
# COUNT:392, 目的関数:0.476079654210401
# COUNT:393, 目的関数:0.47605491309891995
# COUNT:394, 目的関数:0.47603032537880685
# COUNT:395, 目的関数:0.47600588997462745
# COUNT:396, 目的関数:0.47598160581969884
# COUNT:397, 目的関数:0.4759574718560043
# COUNT:398, 目的関数:0.475933487034112
# COUNT:399, 目的関数:0.4759096503130921
# COUNT:400, 目的関数:0.47588596066043876
# COUNT:401, 目的関数:0.47586241705198723
# COUNT:402, 目的関数:0.47583901847183696
# COUNT:403, 目的関数:0.47581576391227326
# COUNT:404, 目的関数:0.4757926523736889
# COUNT:405, 目的関数:0.4757696828645098
# COUNT:406, 目的関数:0.47574685440111764
# COUNT:407, 目的関数:0.4757241660077768
# COUNT:408, 目的関数:0.47570161671655964
# COUNT:409, 目的関数:0.47567920556727333
# COUNT:410, 目的関数:0.47565693160738814
# COUNT:411, 目的関数:0.4756347938919659
# COUNT:412, 目的関数:0.4756127914835884
# COUNT:413, 目的関数:0.4755909234522893
# COUNT:414, 目的関数:0.4755691888754837
# COUNT:415, 目的関数:0.47554758683789994
# COUNT:416, 目的関数:0.4755261164315118
# COUNT:417, 目的関数:0.47550477675547137
# COUNT:418, 目的関数:0.4754835669160441
# COUNT:419, 目的関数:0.475462486026542
# COUNT:420, 目的関数:0.47544153320725924
# COUNT:421, 目的関数:0.47542070758540833
# COUNT:422, 目的関数:0.47540000829505635
# COUNT:423, 目的関数:0.4753794344770611
# COUNT:424, 目的関数:0.47535898527901177
# COUNT:425, 目的関数:0.47533865985516577
# COUNT:426, 目的関数:0.4753184573663873
# COUNT:427, 目的関数:0.47529837698008814
# COUNT:428, 目的関数:0.47527841787016906
# COUNT:429, 目的関数:0.47525857921695885
# COUNT:430, 目的関数:0.4752388602071577
# COUNT:431, 目的関数:0.47521926003377957
# COUNT:432, 目的関数:0.4751997778960938
# COUNT:433, 目的関数:0.47518041299957
# COUNT:434, 目的関数:0.4751611645558212
# COUNT:435, 目的関数:0.4751420317825504
# COUNT:436, 目的関数:0.4751230139034938
# COUNT:437, 目的関数:0.47510411014836784
# COUNT:438, 目的関数:0.4750853197528155
# COUNT:439, 目的関数:0.47506664195835263
# COUNT:440, 目的関数:0.47504807601231713
# COUNT:441, 目的関数:0.475029621167815
# COUNT:442, 目的関数:0.475011276683671
# COUNT:443, 目的関数:0.47499304182437657
# COUNT:444, 目的関数:0.4749749158600393
# COUNT:445, 目的関数:0.4749568980663342
# COUNT:446, 目的関数:0.4749389877244539
# COUNT:447, 目的関数:0.47492118412106027
# COUNT:448, 目的関数:0.47490348654823467
# COUNT:449, 目的関数:0.4748858943034323
# COUNT:450, 目的関数:0.47486840668943403
# COUNT:451, 目的関数:0.474851023014299
# COUNT:452, 目的関数:0.474833742591319
# COUNT:453, 目的関数:0.4748165647389723
# COUNT:454, 目的関数:0.47479948878087863
# COUNT:455, 目的関数:0.4747825140457542
# COUNT:456, 目的関数:0.47476563986736686
# COUNT:457, 目的関数:0.47474886558449186
# COUNT:458, 目的関数:0.474732190540869
# COUNT:459, 目的関数:0.47471561408515994
# COUNT:460, 目的関数:0.47469913557090365
# COUNT:461, 目的関数:0.47468275435647567
# COUNT:462, 目的関数:0.4746664698050467
# COUNT:463, 目的関数:0.4746502812845383
# COUNT:464, 目的関数:0.47463418816758607
# COUNT:465, 目的関数:0.4746181898314955
# COUNT:466, 目的関数:0.4746022856582037
# COUNT:467, 目的関数:0.47458647503423845
# COUNT:468, 目的関数:0.47457075735068077
# COUNT:469, 目的関数:0.4745551320031228
# COUNT:470, 目的関数:0.47453959839163173
# COUNT:471, 目的関数:0.47452415592071095
# COUNT:472, 目的関数:0.47450880399926165
# COUNT:473, 目的関数:0.4744935420405455
# COUNT:474, 目的関数:0.474478369462148
# COUNT:475, 目的関数:0.47446328568594104
# COUNT:476, 目的関数:0.47444829013804773
# COUNT:477, 目的関数:0.47443338224880405
# COUNT:478, 目的関数:0.47441856145272593
# COUNT:479, 目的関数:0.47440382718847174
# COUNT:480, 目的関数:0.47438917889880855
# COUNT:481, 目的関数:0.474374616030577
# COUNT:482, 目的関数:0.47436013803465726
# COUNT:483, 目的関数:0.4743457443659341
# COUNT:484, 目的関数:0.47433143448326553
# COUNT:485, 目的関数:0.4743172078494459
# COUNT:486, 目的関数:0.47430306393117716
# COUNT:487, 目的関数:0.47428900219903225
# COUNT:488, 目的関数:0.4742750221274247
# COUNT:489, 目的関数:0.47426112319457764
# COUNT:490, 目的関数:0.47424730488248945
# COUNT:491, 目的関数:0.4742335666769041
# COUNT:492, 目的関数:0.4742199080672792
# COUNT:493, 目的関数:0.4742063285467561
# COUNT:494, 目的関数:0.4741928276121281
# COUNT:495, 目的関数:0.47417940476381154
# COUNT:496, 目的関数:0.47416605950581453
# COUNT:497, 目的関数:0.4741527913457085
# COUNT:498, 目的関数:0.47413959979459763
# COUNT:499, 目的関数:0.4741264843670906
# COUNT:500, 目的関数:0.47411344458127175
# COUNT:501, 目的関数:0.4741004799586715
# COUNT:502, 目的関数:0.4740875900242388
# COUNT:503, 目的関数:0.4740747743063143
# COUNT:504, 目的関数:0.4740620323366002
# COUNT:505, 目的関数:0.4740493636501347
# COUNT:506, 目的関数:0.474036767785263
# COUNT:507, 目的関数:0.4740242442836122
# COUNT:508, 目的関数:0.4740117926900635
# COUNT:509, 目的関数:0.4739994125527255
# COUNT:510, 目的関数:0.4739871034229089
# COUNT:511, 目的関数:0.47397486485509954
# COUNT:512, 目的関数:0.4739626964069332
# COUNT:513, 目的関数:0.4739505976391706
# COUNT:514, 目的関数:0.47393856811567053
# COUNT:515, 目的関数:0.473926607403366
# COUNT:516, 目的関数:0.47391471507224037
# COUNT:517, 目的関数:0.4739028906953001
# COUNT:518, 目的関数:0.4738911338485533
# COUNT:519, 目的関数:0.4738794441109832
# COUNT:520, 目的関数:0.47386782106452613
# COUNT:521, 目的関数:0.47385626429404654
# COUNT:522, 目的関数:0.4738447733873147
# COUNT:523, 目的関数:0.4738333479349819
# COUNT:524, 目的関数:0.4738219875305597
# COUNT:525, 目的関数:0.473810691770394
# COUNT:526, 目的関数:0.47379946025364567
# COUNT:527, 目的関数:0.47378829258226635
# COUNT:528, 目的関数:0.4737771883609763
# COUNT:529, 目的関数:0.4737661471972427
# COUNT:530, 目的関数:0.4737551687012585
# COUNT:531, 目的関数:0.4737442524859185
# COUNT:532, 目的関数:0.4737333981668021
# COUNT:533, 目的関数:0.4737226053621479
# COUNT:534, 目的関数:0.473711873692835
# COUNT:535, 目的関数:0.4737012027823616
# COUNT:536, 目的関数:0.4736905922568244
# COUNT:537, 目的関数:0.47368004174489736
# COUNT:538, 目的関数:0.47366955087781437
# COUNT:539, 目的関数:0.4736591192893443
# COUNT:540, 目的関数:0.47364874661577594
# COUNT:541, 目的関数:0.4736384324958947
# COUNT:542, 目的関数:0.47362817657096595
# COUNT:543, 目的関数:0.47361797848471343
# COUNT:544, 目的関数:0.4736078378833004
# COUNT:545, 目的関数:0.47359775441531254
# COUNT:546, 目的関数:0.4735877277317358
# COUNT:547, 目的関数:0.47357775748594144
# COUNT:548, 目的関数:0.4735678433336645
# COUNT:549, 目的関数:0.4735579849329865
# COUNT:550, 目的関数:0.47354818194431825
# COUNT:551, 目的関数:0.47353843403038
# COUNT:552, 目的関数:0.4735287408561853
# COUNT:553, 目的関数:0.47351910208902176
# COUNT:554, 目的関数:0.47350951739843483
# COUNT:555, 目的関数:0.4734999864562094
# COUNT:556, 目的関数:0.47349050893635325
# COUNT:557, 目的関数:0.47348108451507925
# COUNT:558, 目的関数:0.4734717128707892
# COUNT:559, 目的関数:0.4734623936840564
# COUNT:560, 目的関数:0.47345312663760963
# COUNT:561, 目的関数:0.47344391141631587
# COUNT:562, 目的関数:0.4734347477071648
# COUNT:563, 目的関数:0.473425635199252
# COUNT:564, 目的関数:0.4734165735837627
# COUNT:565, 目的関数:0.47340756255395616
# COUNT:566, 目的関数:0.4733986018051508
# COUNT:567, 目的関数:0.4733896910347071
# COUNT:568, 目的関数:0.47338082994201214
# COUNT:569, 目的関数:0.4733720182284651
# COUNT:570, 目的関数:0.47336325559746173
# COUNT:571, 目的関数:0.47335454175437947
# COUNT:572, 目的関数:0.47334587640656106
# COUNT:573, 目的関数:0.4733372592633017
# COUNT:574, 目的関数:0.4733286900358325
# COUNT:575, 目的関数:0.4733201684373081
# COUNT:576, 目的関数:0.47331169418278896
# COUNT:577, 目的関数:0.4733032669892304
# COUNT:578, 目的関数:0.47329488657546587
# COUNT:579, 目的関数:0.4732865526621949
# COUNT:580, 目的関数:0.4732782649719665
# COUNT:581, 目的関数:0.4732700232291682
# COUNT:582, 目的関数:0.47326182716000975
# COUNT:583, 目的関数:0.4732536764925116
# COUNT:584, 目的関数:0.47324557095649017
# COUNT:585, 目的関数:0.47323751028354427
# COUNT:586, 目的関数:0.47322949420704263
# COUNT:587, 目的関数:0.4732215224621103
# COUNT:588, 目的関数:0.4732135947856161
# COUNT:589, 目的関数:0.473205710916158
# COUNT:590, 目的関数:0.47319787059405216
# COUNT:591, 目的関数:0.4731900735613207
# COUNT:592, 目的関数:0.47318231956167567
# COUNT:593, 目的関数:0.47317460834051034
# COUNT:594, 目的関数:0.4731669396448846
# COUNT:595, 目的関数:0.47315931322351307
# COUNT:596, 目的関数:0.4731517288267538
# COUNT:597, 目的関数:0.47314418620659476
# COUNT:598, 目的関数:0.473136685116643
# COUNT:599, 目的関数:0.47312922531211155
# COUNT:600, 目的関数:0.4731218065498094
# COUNT:601, 目的関数:0.47311442858812713
# COUNT:602, 目的関数:0.473107091187029
# COUNT:603, 目的関数:0.4730997941080377
# COUNT:604, 目的関数:0.47309253711422516
# COUNT:605, 目的関数:0.47308531997020026
# COUNT:606, 目的関数:0.47307814244209884
# COUNT:607, 目的関数:0.473071004297571
# COUNT:608, 目的関数:0.47306390530577097
# COUNT:609, 目的関数:0.473056845237346
# COUNT:610, 目的関数:0.47304982386442596
# COUNT:611, 目的関数:0.4730428409606104
# COUNT:612, 目的関数:0.4730358963009617
# COUNT:613, 目的関数:0.473028989661991
# COUNT:614, 目的関数:0.47302212082164957
# COUNT:615, 目的関数:0.47301528955931776
# COUNT:616, 目的関数:0.4730084956557946
# COUNT:617, 目的関数:0.4730017388932874
# COUNT:618, 目的関数:0.4729950190554032
# COUNT:619, 目的関数:0.4729883359271359
# COUNT:620, 目的関数:0.4729816892948587
# COUNT:621, 目的関数:0.4729750789463123
# COUNT:622, 目的関数:0.4729685046705974
# COUNT:623, 目的関数:0.4729619662581622
# COUNT:624, 目的関数:0.47295546350079504
# COUNT:625, 目的関数:0.47294899619161296
# COUNT:626, 目的関数:0.47294256412505414
# COUNT:627, 目的関数:0.47293616709686614
# COUNT:628, 目的関数:0.47292980490409847
# COUNT:629, 目的関数:0.47292347734509277
# COUNT:630, 目的関数:0.4729171842194731
# COUNT:631, 目的関数:0.47291092532813706
# COUNT:632, 目的関数:0.4729047004732471
# COUNT:633, 目的関数:0.47289850945822115
# COUNT:634, 目的関数:0.4728923520877232
# COUNT:635, 目的関数:0.4728862281676556
# COUNT:636, 目的関数:0.47288013750514996
# COUNT:637, 目的関数:0.47287407990855723
# COUNT:638, 目的関数:0.47286805518744085
# COUNT:639, 目的関数:0.472862063152567
# COUNT:640, 目的関数:0.4728561036158966
# COUNT:641, 目的関数:0.4728501763905765
# COUNT:642, 目的関数:0.4728442812909316
# COUNT:643, 目的関数:0.472838418132456
# COUNT:644, 目的関数:0.4728325867318052
# COUNT:645, 目的関数:0.4728267869067878
# COUNT:646, 目的関数:0.4728210184763577
# COUNT:647, 目的関数:0.472815281260605
# COUNT:648, 目的関数:0.4728095750807493
# COUNT:649, 目的関数:0.4728038997591313
# COUNT:650, 目的関数:0.4727982551192044
# COUNT:651, 目的関数:0.47279264098552853
# COUNT:652, 目的関数:0.47278705718376013
# COUNT:653, 目的関数:0.47278150354064635
# COUNT:654, 目的関数:0.4727759798840164
# COUNT:655, 目的関数:0.47277048604277483
# COUNT:656, 目的関数:0.47276502184689334
# COUNT:657, 目的関数:0.4727595871274034
# COUNT:658, 目的関数:0.4727541817163897
# COUNT:659, 目的関数:0.47274880544698195
# COUNT:660, 目的関数:0.47274345815334756
# COUNT:661, 目的関数:0.47273813967068556
# COUNT:662, 目的関数:0.4727328498352177
# COUNT:663, 目的関数:0.4727275884841832
# COUNT:664, 目的関数:0.4727223554558309
# COUNT:665, 目的関数:0.4727171505894118
# COUNT:666, 目的関数:0.47271197372517293
# COUNT:667, 目的関数:0.47270682470435005
# COUNT:668, 目的関数:0.4727017033691611
# COUNT:669, 目的関数:0.4726966095627994
# COUNT:670, 目的関数:0.47269154312942674
# COUNT:671, 目的関数:0.47268650391416595
# COUNT:672, 目的関数:0.47268149176309726
# COUNT:673, 目的関数:0.4726765065232479
# COUNT:674, 目的関数:0.4726715480425878
# COUNT:675, 目的関数:0.47266661617002326
# COUNT:676, 目的関数:0.4726617107553894
# COUNT:677, 目的関数:0.47265683164944444
# COUNT:678, 目的関数:0.4726519787038634
# COUNT:679, 目的関数:0.4726471517712326
# COUNT:680, 目的関数:0.4726423507050414
# COUNT:681, 目的関数:0.47263757535967843
# COUNT:682, 目的関数:0.4726328255904233
# COUNT:683, 目的関数:0.47262810125344235
# COUNT:684, 目的関数:0.4726234022057817
# COUNT:685, 目的関数:0.4726187283053616
# COUNT:686, 目的関数:0.47261407941096967
# COUNT:687, 目的関数:0.4726094553822567
# COUNT:688, 目的関数:0.4726048560797288
# COUNT:689, 目的関数:0.4726002813647437
# COUNT:690, 目的関数:0.4725957310995021
# COUNT:691, 目的関数:0.4725912051470463
# COUNT:692, 目的関数:0.4725867033712504
# COUNT:693, 目的関数:0.4725822256368164
# COUNT:694, 目的関数:0.4725777718092684
# COUNT:695, 目的関数:0.4725733417549485
# COUNT:696, 目的関数:0.4725689353410079
# COUNT:697, 目的関数:0.4725645524354054
# COUNT:698, 目的関数:0.47256019290689927
# COUNT:699, 目的関数:0.47255585662504257
# COUNT:700, 目的関数:0.4725515434601784
# COUNT:701, 目的関数:0.4725472532834349
# COUNT:702, 目的関数:0.47254298596671734
# COUNT:703, 目的関数:0.47253874138270674
# COUNT:704, 目的関数:0.4725345194048519
# COUNT:705, 目的関数:0.4725303199073656
# COUNT:706, 目的関数:0.472526142765219
# COUNT:707, 目的関数:0.47252198785413657
# COUNT:708, 目的関数:0.47251785505059113
# COUNT:709, 目的関数:0.47251374423179954
# COUNT:710, 目的関数:0.4725096552757163
# COUNT:711, 目的関数:0.47250558806103016
# COUNT:712, 目的関数:0.47250154246715814
# COUNT:713, 目的関数:0.4724975183742416
# COUNT:714, 目的関数:0.47249351566314046
# COUNT:715, 目的関数:0.47248953421542916
# COUNT:716, 目的関数:0.4724855739133923
# COUNT:717, 目的関数:0.4724816346400183
# COUNT:718, 目的関数:0.4724777162789969
# COUNT:719, 目的関数:0.47247381871471295
# COUNT:720, 目的関数:0.4724699418322419
# COUNT:721, 目的関数:0.47246608551734676
# COUNT:722, 目的関数:0.4724622496564717
# COUNT:723, 目的関数:0.47245843413673827
# COUNT:724, 目的関数:0.47245463884594174
# COUNT:725, 目的関数:0.4724508636725451
# COUNT:726, 目的関数:0.47244710850567617
# COUNT:727, 目的関数:0.472443373235123
# COUNT:728, 目的関数:0.4724396577513278
# COUNT:729, 目的関数:0.47243596194538545
# COUNT:730, 目的関数:0.4724322857090369
# COUNT:731, 目的関数:0.47242862893466564
# COUNT:732, 目的関数:0.472424991515295
# COUNT:733, 目的関数:0.47242137334458156
# COUNT:734, 目的関数:0.4724177743168121
# COUNT:735, 目的関数:0.47241419432690007
# COUNT:736, 目的関数:0.47241063327038063
# COUNT:737, 目的関数:0.4724070910434072
# COUNT:738, 目的関数:0.4724035675427463
# COUNT:739, 目的関数:0.47240006266577605
# COUNT:740, 目的関数:0.472396576310479
# COUNT:741, 目的関数:0.4723931083754403
# COUNT:742, 目的関数:0.4723896587598438
# COUNT:743, 目的関数:0.4723862273634667
# COUNT:744, 目的関数:0.47238281408667776
# COUNT:745, 目的関数:0.4723794188304316
# COUNT:746, 目的関数:0.4723760414962656
# COUNT:747, 目的関数:0.4723726819862965
# COUNT:748, 目的関数:0.472369340203217
# COUNT:749, 目的関数:0.4723660160502897
# COUNT:750, 目的関数:0.47236270943134706
# COUNT:751, 目的関数:0.47235942025078437
# COUNT:752, 目的関数:0.47235614841355833
# COUNT:753, 目的関数:0.47235289382518275
# COUNT:754, 目的関数:0.47234965639172416
# COUNT:755, 目的関数:0.4723464360197997
# COUNT:756, 目的関数:0.4723432326165726
# COUNT:757, 目的関数:0.47234004608974867
# COUNT:758, 目的関数:0.47233687634757415
# COUNT:759, 目的関数:0.47233372329882967
# COUNT:760, 目的関数:0.47233058685282986
# COUNT:761, 目的関数:0.4723274669194177
# COUNT:762, 目的関数:0.47232436340896067
# COUNT:763, 目的関数:0.4723212762323519
# COUNT:764, 目的関数:0.47231820530100044
# COUNT:765, 目的関数:0.4723151505268319
# COUNT:766, 目的関数:0.4723121118222848
# COUNT:767, 目的関数:0.4723090891003067
# COUNT:768, 目的関数:0.47230608227435095
# COUNT:769, 目的関数:0.4723030912583733
# COUNT:770, 目的関数:0.47230011596682997
# COUNT:771, 目的関数:0.4722971563146719
# COUNT:772, 目的関数:0.472294212217345
# COUNT:773, 目的関数:0.47229128359078415
# COUNT:774, 目的関数:0.47228837035141136
# COUNT:775, 目的関数:0.47228547241613267
# COUNT:776, 目的関数:0.472282589702335
# COUNT:777, 目的関数:0.472279722127883
# COUNT:778, 目的関数:0.47227686961111565
# COUNT:779, 目的関数:0.4722740320708446
# COUNT:780, 目的関数:0.472271209426349
# COUNT:781, 目的関数:0.4722684015973751
# COUNT:782, 目的関数:0.4722656085041308
# COUNT:783, 目的関数:0.47226283006728553
# COUNT:784, 目的関数:0.47226006620796424
# COUNT:785, 目的関数:0.4722573168477473
# COUNT:786, 目的関数:0.4722545819086652
# COUNT:787, 目的関数:0.4722518613131982
# COUNT:788, 目的関数:0.4722491549842715
# COUNT:789, 目的関数:0.472246462845253
# COUNT:790, 目的関数:0.4722437848199517
# COUNT:791, 目的関数:0.4722411208326132
# COUNT:792, 目的関数:0.47223847080791764
# COUNT:793, 目的関数:0.4722358346709777
# COUNT:794, 目的関数:0.47223321234733495
# COUNT:795, 目的関数:0.47223060376295706
# COUNT:796, 目的関数:0.47222800884423677
# COUNT:797, 目的関数:0.4722254275179867
# COUNT:798, 目的関数:0.47222285971143857
# COUNT:799, 目的関数:0.4722203053522406
# COUNT:800, 目的関数:0.47221776436845353
# COUNT:801, 目的関数:0.47221523668854987
# COUNT:802, 目的関数:0.4722127222414096
# COUNT:803, 目的関数:0.4722102209563191
# COUNT:804, 目的関数:0.47220773276296746
# COUNT:805, 目的関数:0.472205257591445
# COUNT:806, 目的関数:0.47220279537223936
# COUNT:807, 目的関数:0.4722003460362355
# COUNT:808, 目的関数:0.4721979095147101
# COUNT:809, 目的関数:0.4721954857393314
# COUNT:810, 目的関数:0.4721930746421562
# COUNT:811, 目的関数:0.4721906761556279
# COUNT:812, 目的関数:0.47218829021257197
# COUNT:813, 目的関数:0.472185916746197
# COUNT:814, 目的関数:0.4721835556900895
# COUNT:815, 目的関数:0.47218120697821286
# COUNT:816, 目的関数:0.47217887054490465
# COUNT:817, 目的関数:0.4721765463248748
# COUNT:818, 目的関数:0.4721742342532028
# COUNT:819, 目的関数:0.4721719342653352
# COUNT:820, 目的関数:0.4721696462970844
# COUNT:821, 目的関数:0.4721673702846251
# COUNT:822, 目的関数:0.4721651061644931
# COUNT:823, 目的関数:0.47216285387358253
# COUNT:824, 目的関数:0.47216061334914405
# COUNT:825, 目的関数:0.4721583845287828
# COUNT:826, 目的関数:0.47215616735045457
# COUNT:827, 目的関数:0.472153961752466
# COUNT:828, 目的関数:0.47215176767347145
# COUNT:829, 目的関数:0.47214958505247023
# COUNT:830, 目的関数:0.4721474138288058
# COUNT:831, 目的関数:0.472145253942162
# COUNT:832, 目的関数:0.4721431053325635
# COUNT:833, 目的関数:0.4721409679403694
# COUNT:834, 目的関数:0.4721388417062775
# COUNT:835, 目的関数:0.47213672657131545
# COUNT:836, 目的関数:0.47213462247684446
# COUNT:837, 目的関数:0.472132529364553
# COUNT:838, 目的関数:0.4721304471764574
# COUNT:839, 目的関数:0.47212837585489953
# COUNT:840, 目的関数:0.47212631534254296
# COUNT:841, 目的関数:0.4721242655823741
# COUNT:842, 目的関数:0.4721222265176971
# COUNT:843, 目的関数:0.4721201980921339
# COUNT:844, 目的関数:0.4721181802496224
# COUNT:845, 目的関数:0.4721161729344129
# COUNT:846, 目的関数:0.47211417609106765
# COUNT:847, 目的関数:0.47211218966445895
# COUNT:848, 目的関数:0.4721102135997665
# COUNT:849, 目的関数:0.4721082478424757
# COUNT:850, 目的関数:0.47210629233837637
# COUNT:851, 目的関数:0.47210434703356086
# COUNT:852, 目的関数:0.4721024118744211
# COUNT:853, 目的関数:0.4721004868076485
# COUNT:854, 目的関数:0.47209857178023107
# COUNT:855, 目的関数:0.4720966667394512
# COUNT:856, 目的関数:0.4720947716328852
# COUNT:857, 目的関数:0.4720928864084009
# COUNT:858, 目的関数:0.4720910110141555
# COUNT:859, 目的関数:0.4720891453985948
# COUNT:860, 目的関数:0.4720872895104504
# COUNT:861, 目的関数:0.47208544329873836
# COUNT:862, 目的関数:0.47208360671275773
# COUNT:863, 目的関数:0.47208177970208925
# COUNT:864, 目的関数:0.47207996221659276
# COUNT:865, 目的関数:0.4720781542064056
# COUNT:866, 目的関数:0.4720763556219416
# COUNT:867, 目的関数:0.47207456641388923
# COUNT:868, 目的関数:0.47207278653321
# COUNT:869, 目的関数:0.47207101593113576
# COUNT:870, 目的関数:0.4720692545591688
# COUNT:871, 目的関数:0.4720675023690794
# COUNT:872, 目的関数:0.47206575931290384
# COUNT:873, 目的関数:0.4720640253429437
# COUNT:874, 目的関数:0.4720623004117634
# COUNT:875, 目的関数:0.4720605844721892
# COUNT:876, 目的関数:0.472058877477308
# COUNT:877, 目的関数:0.4720571793804647
# COUNT:878, 目的関数:0.47205549013526127
# COUNT:879, 目的関数:0.4720538096955556
# COUNT:880, 目的関数:0.4720521380154595
# COUNT:881, 目的関数:0.4720504750493369
# COUNT:882, 目的関数:0.4720488207518031
# COUNT:883, 目的関数:0.4720471750777235
# COUNT:884, 目的関数:0.4720455379822105
# COUNT:885, 目的関数:0.47204390942062363
# COUNT:886, 目的関数:0.47204228934856746
# COUNT:887, 目的関数:0.4720406777218904
# COUNT:888, 目的関数:0.47203907449668336
# COUNT:889, 目的関数:0.4720374796292775
# COUNT:890, 目的関数:0.47203589307624333
# COUNT:891, 目的関数:0.47203431479439056
# COUNT:892, 目的関数:0.47203274474076373
# COUNT:893, 目的関数:0.47203118287264406
# COUNT:894, 目的関数:0.4720296291475457
# COUNT:895, 目的関数:0.4720280835232157
# COUNT:896, 目的関数:0.4720265459576318
# COUNT:897, 目的関数:0.4720250164090024
# COUNT:898, 目的関数:0.47202349483576284
# COUNT:899, 目的関数:0.4720219811965766
# COUNT:900, 目的関数:0.472020475450333
# COUNT:901, 目的関数:0.4720189775561446
# COUNT:902, 目的関数:0.47201748747334793
# COUNT:903, 目的関数:0.47201600516150094
# COUNT:904, 目的関数:0.4720145305803827
# COUNT:905, 目的関数:0.47201306368999035
# COUNT:906, 目的関数:0.4720116044505393
# COUNT:907, 目的関数:0.4720101528224627
# COUNT:908, 目的関数:0.4720087087664079
# COUNT:909, 目的関数:0.47200727224323596
# COUNT:910, 目的関数:0.47200584321402217
# COUNT:911, 目的関数:0.47200442164005224
# COUNT:912, 目的関数:0.47200300748282326
# COUNT:913, 目的関数:0.47200160070404
# COUNT:914, 目的関数:0.4720002012656174
# COUNT:915, 目的関数:0.47199880912967557
# COUNT:916, 目的関数:0.4719974242585392
# COUNT:917, 目的関数:0.47199604661474
# COUNT:918, 目的関数:0.4719946761610108
# COUNT:919, 目的関数:0.47199331286028706
# COUNT:920, 目的関数:0.4719919566757053
# COUNT:921, 目的関数:0.4719906075706008
# COUNT:922, 目的関数:0.4719892655085081
# COUNT:923, 目的関数:0.4719879304531587
# COUNT:924, 目的関数:0.4719866023684807
# COUNT:925, 目的関数:0.471985281218597
# COUNT:926, 目的関数:0.47198396696782396
# COUNT:927, 目的関数:0.47198265958067165
# COUNT:928, 目的関数:0.47198135902184085
# COUNT:929, 目的関数:0.4719800652562241
# COUNT:930, 目的関数:0.47197877824890205
# COUNT:931, 目的関数:0.4719774979651448
# COUNT:932, 目的関数:0.47197622437040926
# COUNT:933, 目的関数:0.4719749574303391
# COUNT:934, 目的関数:0.471973697110762
# COUNT:935, 目的関数:0.4719724433776909
# COUNT:936, 目的関数:0.4719711961973213
# COUNT:937, 目的関数:0.47196995553603105
# COUNT:938, 目的関数:0.47196872136037776
# COUNT:939, 目的関数:0.47196749363709994
# COUNT:940, 目的関数:0.4719662723331155
# COUNT:941, 目的関数:0.47196505741551864
# COUNT:942, 目的関数:0.47196384885158144
# COUNT:943, 目的関数:0.4719626466087516
# COUNT:944, 目的関数:0.4719614506546513
# COUNT:945, 目的関数:0.4719602609570765
# COUNT:946, 目的関数:0.47195907748399646
# COUNT:947, 目的関数:0.4719579002035521
# COUNT:948, 目的関数:0.47195672908405467
# COUNT:949, 目的関数:0.4719555640939856
# COUNT:950, 目的関数:0.4719544052019953
# COUNT:951, 目的関数:0.4719532523769021
# COUNT:952, 目的関数:0.4719521055876909
# COUNT:953, 目的関数:0.4719509648035128
# COUNT:954, 目的関数:0.47194982999368396
# COUNT:955, 目的関数:0.47194870112768506
# COUNT:956, 目的関数:0.4719475781751593
# COUNT:957, 目的関数:0.471946461105912
# COUNT:958, 目的関数:0.4719453498899109
# COUNT:959, 目的関数:0.47194424449728306
# COUNT:960, 目的関数:0.47194314489831535
# COUNT:961, 目的関数:0.4719420510634534
# COUNT:962, 目的関数:0.4719409629633003
# COUNT:963, 目的関数:0.47193988056861585
# COUNT:964, 目的関数:0.4719388038503162
# COUNT:965, 目的関数:0.47193773277947254
# COUNT:966, 目的関数:0.4719366673273091
# COUNT:967, 目的関数:0.47193560746520496
# COUNT:968, 目的関数:0.47193455316468996
# COUNT:969, 目的関数:0.47193350439744686
# COUNT:970, 目的関数:0.47193246113530835
# COUNT:971, 目的関数:0.4719314233502574
# COUNT:972, 目的関数:0.47193039101442535
# COUNT:973, 目的関数:0.4719293641000918
# COUNT:974, 目的関数:0.47192834257968413
# COUNT:975, 目的関数:0.47192732642577545
# COUNT:976, 目的関数:0.4719263156110858
# COUNT:977, 目的関数:0.4719253101084784
# COUNT:978, 目的関数:0.4719243098909614
# COUNT:979, 目的関数:0.47192331493168593
# COUNT:980, 目的関数:0.4719223252039457
# COUNT:981, 目的関数:0.4719213406811754
# COUNT:982, 目的関数:0.4719203613369514
# COUNT:983, 目的関数:0.4719193871449896
# COUNT:984, 目的関数:0.47191841807914464
# COUNT:985, 目的関数:0.47191745411340996
# COUNT:986, 目的関数:0.47191649522191703
# COUNT:987, 目的関数:0.4719155413789338
# COUNT:988, 目的関数:0.47191459255886425
# COUNT:989, 目的関数:0.4719136487362478
# COUNT:990, 目的関数:0.4719127098857583
# COUNT:991, 目的関数:0.47191177598220374
# COUNT:992, 目的関数:0.47191084700052466
# COUNT:993, 目的関数:0.4719099229157946
# COUNT:994, 目的関数:0.4719090037032186
# COUNT:995, 目的関数:0.47190808933813144
# COUNT:996, 目的関数:0.47190717979599983
# COUNT:997, 目的関数:0.47190627505241806
# COUNT:998, 目的関数:0.4719053750831105
# COUNT:999, 目的関数:0.47190447986392825
# COUNT:1000, 目的関数:0.47190358937085086

# %%
from sklearn.metrics import accuracy_score

y_pred = slr.predict(X_test)
print("Accurcy: {:.2f}".format(accuracy_score(y_test, y_pred)))
# Out:
# Accurcy: 0.77

# %% [markdown]
# ### シグモイド関数
# コーディング
# <br>シグモイド関数を実装しましょう。
# <br>
# $$
# g(z) = \frac{1}{1+e^{−z}}
# $$
# <br>
# <br>正しく動作しているかを確認するために、この関数に-10から10の値を入力したときの出力をプロットしておいてください。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import math
# mathパッケージで自然対数の底eを定義する
e = math.e

def sigmoid(z):
    return 1/(1+(e**-z))

sigmoid_check = np.zeros(21)
for i in range(-10, 11):
    output = sigmoid(i)
#     print("z:{}, g(z):{}".format(i, output))
    sigmoid_check[i+10] = output
    
# define Initial setting 
fig, ax = plt.subplots(figsize=(6, 6))
fig.patch.set_facecolor('skyblue')
fig.patch.set_alpha(1)
ax.patch.set_facecolor('white')
ax.patch.set_alpha(1)

plt.grid()

# plot 
plt.title("sigmoid function")
plt.xlabel("z")

plt.plot(sigmoid_check)

# %% [markdown]
# ### 目的関数
# 以下の数式で表されるロジスティック回帰の目的関数Jを実装してください。
# <br>この数式には正則化項が含まれています。
# <br>
# $$
# J(\theta)=  \frac{1}{m}  \sum_{i=1}^{m}[−y^{(i)} log(h_θ(x^{(i)})) − (1−y^{(i)}) log(1−h_θ(x^{(i)}))] +
# \frac{λ}{2m}\sum_{j=1}^n
# θ^2_j
# $$
# $$
# h_θ(x) = g(θ^T x)
# $$
# $$
# g(z) = \frac{1}{1+e^{−z}}
# $$
# $$
# Jθ:目的関数
# $$
# $$
# m: 入力されるデータの数
# $$
# $$
# hθ(): 仮定関数
# $$
# $$
# x: 特徴量ベクトル
# $$
# $$
# θ: パラメータベクトル
# $$
# $$
# g() : シグモイド関数
# $$
# $$
# x(i): i番目のサンプルの特徴量ベクトル
# $$
# $$
# y(i) : i番目のサンプルの正解ラベル
# $$
# $$
# θj: j番目のパラメータ（重み）
# $$
# $$
# λ: 正則化パラメータ
# $$

# %% [markdown]
# ### 最急降下法
# 最急降下法により学習させてください。バイアス項およびj番目のパラメータの更新には以下の式を使います。
# <br>
# $$
# j=0：バイアス項
# $$
# $$
# \frac{\partial J(\theta)}{\partial \theta_0} = \frac{1}{m}  \sum_{i=1}^{m}(h_θ(x^{(i)}) − y^{(i)})x_j^{(i)}
# $$
# $$
# j\geq 1：バイアス項以外
# $$
# $$
# \frac{\partial J(\theta)}{\partial \theta_j} = \biggl(\frac{1}{m}  \sum_{i=1}^{m}(h_θ(x^{(i)}) − y^{(i)})x_j^{(i)} \biggr) + \frac{λ}{m}\theta_j
# $$
#
# <br>
# <br>
# $$
# i : サンプルのインデックス
# $$
# $$
# j : 特徴量のインデックス
# $$

# %% [markdown]
# ## 検証

# %% [markdown]
# ### 【問題2】学習曲線のプロット
# 学習曲線をプロットしてください。

# %%
df_loss = pd.DataFrame(slr.loss)
val_loss = pd.DataFrame(slr.val_loss)


# define Initial setting 
fig, ax = plt.subplots(figsize=(6, 6))
fig.patch.set_facecolor('skyblue')
fig.patch.set_alpha(1)
ax.patch.set_facecolor('white')
ax.patch.set_alpha(1)
# ax.set_yscale('log') 
plt.grid()


# plot a cross section of mt.Fuji
plt.title("model loss")
plt.xlabel("iter")
plt.ylabel("loss")

p1, = plt.plot(df_loss, label='o')
p2, = plt.plot(val_loss, label='*')
plt.legend([p1, p2],["train_loss", "val_loss"], loc=1) # 凡例の位置, 名前の指定

plt.grid()
plt.show()

# %% [markdown]
# 過学習を起こしてしまっている。実務では上のような状態は避けなければならない。

# %% [markdown]
# ### 【問題3】指標値の算出
# 分類に関する指標値で精度を確認してください。

# %%
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score


"""

get scores: accuracy, pecision, recall, F measure

"""
def get_scores(y_test, y_pred):
    scores_array = np.hstack((accuracy_score(y_test, y_pred), 
                             precision_score(y_test, y_pred),
                             recall_score(y_test, y_pred),
                             f1_score(y_test, y_pred)))
    return scores_array
    
scores = get_scores(y_test, y_pred)
index_score = [ "accuracy","precision","recall","f1"]
scores = pd.DataFrame(scores, index=index_score, columns={'iris_data':0})
scores
# Out:
#            iris_data
# accuracy    0.766667
# precision   0.650000
# recall      1.000000
# f1          0.787879

# %% [markdown]
# ### 【問題4】決定領域の可視化
# 2値分類のデータセットに対して決定領域を可視化してください。

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches

def decision_region(X_train, y_train, model, step=0.01, title='decision region', xlabel='xlabel', ylabel='ylabel', target_names=['versicolor', 'virginica']):
    """
    Draw the decision area of the model learned by binary classification with two dimensional 
    feature quantity.
     The color of the background is drawn from the estimated value by the learned model.
     The point of the scatter diagram is learning data.

     Parameters
     ------------------
     X_train: ndarray, shape (n_samples, 2)
         Characteristic quantity of learning data
     y_train: ndarray, shape (n_samples,)
         Correct value of learning data
     model: object
         **** Insert Instantus of the learned model
     step: float, (default: 0.1)
         Set interval to calculate estimated value
     title: str
         Give the text of the title of the graph
     xlabel, ylabel: str
         Give sentences of axis labels
     target_names =: list of str
         Give a list of legends
    """
    # define Initial setting 
    fig, ax = plt.subplots(figsize=(6, 6))
    fig.patch.set_facecolor('skyblue')
    fig.patch.set_alpha(1)
    ax.patch.set_facecolor('white')
    ax.patch.set_alpha(1)
    # ax.set_yscale('log') 
    plt.grid()
    
    # setting
    scatter_color = ['red', 'green']
    contourf_color = ['pink', 'skyblue']
    n_class = 2

    # pred
    mesh_f0, mesh_f1  = np.meshgrid(np.arange(np.min(X_train[:,0])-0.5, np.max(X_train[:,0])+0.5, step), np.arange(np.min(X_train[:,1])-0.5, np.max(X_train[:,1])+0.5, step))
    mesh = np.c_[np.ravel(mesh_f0),np.ravel(mesh_f1)]
    pred = model.predict(mesh).reshape(mesh_f0.shape)

    # plot setting title
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
#     fig.patch.set_facecolor('blue')
#     fig.patch.set_alpha(1)
#     ax.patch.set_facecolor('white')
#     ax.patch.set_alpha(1)
#     plt.contourf(mesh_f0, mesh_f1, pred, n_class-1, cmap=ListedColormap(contourf_color))
    plt.contour(mesh_f0, mesh_f1, pred, n_class-1, colors='g', linewidths=5, alpha=0.5)
    
    for i, target in enumerate(set(y_train)):
        plt.scatter(X_train[y_train==target][:, 0], X_train[y_train==target][:, 1], s=150, color=scatter_color[i], label=target_names[i], 
                    marker='x', alpha=0.7)
    patches = [mpatches.Patch(color=scatter_color[i], label=target_names[i]) for i in range(n_class)]
    plt.legend(handles=patches)
    plt.legend()
    plt.show()

# %%
decision_region(X_train, y_train, slr, xlabel='sepal_lenth', ylabel="petal_length")

# %%
df_X_test = pd.DataFrame(X_test)
df_y_test = pd.DataFrame(y_test)
df_y_pred = pd.DataFrame(y_pred)
df_iris = pd.concat([df_X_test, df_y_test, df_y_pred], axis=1)
df_iris.columns = ['petal_length', 'sepal_lenth', 'y_test', 'y_pred']
# df_iris.sort_values(by='y_pred')

# %%
df_versicolor = df_iris[df_iris['y_pred'] == 0]
df_virginica =  df_iris[df_iris['y_pred'] == 1]
df_versicolor.describe()
# Out:
#        petal_length  sepal_lenth  y_test  y_pred
# count     10.000000    10.000000    10.0    10.0
# mean       5.520000     3.900000     0.0     0.0
# std        0.282056     0.478423     0.0     0.0
# min        5.000000     3.000000     0.0     0.0
# 25%        5.425000     3.625000     0.0     0.0
# 50%        5.600000     4.150000     0.0     0.0
# 75%        5.700000     4.200000     0.0     0.0
# max        5.900000     4.500000     0.0     0.0

# %%
df_virginica.describe()
# Out:
#        petal_length  sepal_lenth    y_test  y_pred
# count     20.000000    20.000000  20.00000    20.0
# mean       6.505000     5.180000   0.65000     1.0
# std        0.443046     0.569949   0.48936     0.0
# min        5.800000     4.300000   0.00000     1.0
# 25%        6.175000     4.700000   0.00000     1.0
# 50%        6.450000     5.150000   1.00000     1.0
# 75%        6.725000     5.525000   1.00000     1.0
# max        7.400000     6.300000   1.00000     1.0

# %% [markdown]
# #### 考察
# 仮説では"petal_length"が5cm前後で、'versicolor', 'virginica'が分類され、"sepal_lenth"は、6.3cm前後で分類できるように見えるが、"petal_length"に比べ、信頼区間の精度は劣るのではないかと考えた。
# <br>
# <br> テストデータの予測の結果を見ると、"versicolor"と予測されたグループの"petal_length"の平均が
# 5.52(cm)、標準偏差が0.28、"sepal_lenth"の平均が3.90(cm)、標準偏差が0.48であったのに対し、
# "virginica"と予測されたグループの"petal_length"の平均が
# 6.51(cm)、標準偏差が0.44、"sepal_lenth"の平均が5.18(cm)、標準偏差が0.57であった。
# <br>
# <br>以上から考えると、二つの特徴量の平均差は大きく変わらないが、"sepal_lenth"の標準偏差が大きくなっていることがわかる。これによって、視覚的にも、ロジスティック回帰的にもデータが重なっており、分類が難しくなる。

# %% [markdown]
# ### 【問題5】（アドバンス課題）重みの保存
# 検証が容易になるように、学習した重みを保存および読み込みができるようにしましょう。
# <br>pickleモジュールやnumpy.savezを利用します。

# %%
import pickle

with open('model.pickle', mode='wb') as fp:
    pickle.dump(slr, fp, protocol=2)

# %%
with open('model.pickle', mode='rb') as fp:
    clf = pickle.load(fp)

# %%
print(clf)
# Out:
# <__main__.ScratchLogisticRegression object at 0x1a288bc748>

# %% [markdown]
# ## ディスカッション

# %% [markdown]
# ### 【問題6】分類と回帰
# 最終発表時に以下の内容についてディスカッションを行います。自分なりの意見を用意しておいてください。
# <br>分類問題と回帰問題は本質的に何が異なっていいるか
# <br>
# <br>注意点
# <br>答えがある問いではありません。いろいろな視点から見て理解を深めていきましょう。

# %% [markdown]
# ・具体的数値を予測するのが回帰問題で、種類を見分けるのが分類問題（簡易な回答）
# <br>・その他
